# %%
# %%writefile linear_search.c
# #include <stdio.h>
#
# int main()
# {
#     int arr[100];
#     int n, key;
#     int found = 0;
#
#     printf("========================================\n");
#     printf("        LINEAR SEARCH PROGRAM\n");
#     printf("========================================\n");
#
#     printf("Enter the number of elements: ");
#     scanf("%d", &n);
#
#     printf("\nEnter %d elements:\n", n);
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("Element %d: ", i + 1);
#         scanf("%d", &arr[i]);
#     }
#
#     printf("\nEnter the element to search: ");
#     scanf("%d", &key);
#
#     for(int i = 0; i < n; i++)
#     {
#         if(arr[i] == key)
#         {
#             printf("\nElement %d found at index %d.", key, i);
#             found = 1;
#             break;
#         }
#     }
#
#     if(found == 0)
#     {
#         printf("\nElement %d not found.", key);
#     }
#
#     return 0;
# }
# Out:
# Overwriting linear_search.c

# %%
# %%writefile binary_search.c
# #include <stdio.h>
#
# int main()
# {
#     int arr[100];
#     int n, key;
#     int low, high, mid;
#     int found = 0;
#
#     printf("========================================\n");
#     printf("        BINARY SEARCH PROGRAM\n");
#     printf("========================================\n");
#
#     printf("Enter the number of elements: ");
#     scanf("%d", &n);
#
#     printf("\nEnter %d elements in sorted order:\n", n);
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("Element %d: ", i + 1);
#         scanf("%d", &arr[i]);
#     }
#
#     printf("\nEnter the element to search: ");
#     scanf("%d", &key);
#
#     low = 0;
#     high = n - 1;
#
#     while(low <= high)
#     {
#         mid = (low + high) / 2;
#
#         if(arr[mid] == key)
#         {
#             found = 1;
#             break;
#         }
#         else if(key < arr[mid])
#         {
#             high = mid - 1;
#         }
#         else
#         {
#             low = mid + 1;
#         }
#     }
#
#     if(found)
#     {
#         printf("\nElement %d found at index %d.", key, mid);
#     }
#     else
#     {
#         printf("\nElement %d not found.", key);
#     }
#
#     return 0;
# }
# Out:
# Writing binary_search.c

# %%
# %%writefile bubble_sort.c
# #include <stdio.h>
#
# int main()
# {
#     int arr[100];
#     int n, temp;
#
#     printf("========================================\n");
#     printf("          BUBBLE SORT PROGRAM\n");
#     printf("========================================\n");
#
#     printf("Enter the number of elements: ");
#     scanf("%d", &n);
#
#     printf("\nEnter %d elements:\n", n);
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("Element %d: ", i + 1);
#         scanf("%d", &arr[i]);
#     }
#
#     for(int i = 0; i < n - 1; i++)
#     {
#         for(int j = 0; j < n - i - 1; j++)
#         {
#             if(arr[j] > arr[j + 1])
#             {
#                 temp = arr[j];
#                 arr[j] = arr[j + 1];
#                 arr[j + 1] = temp;
#             }
#         }
#     }
#
#     printf("\nSorted Array (Ascending Order):\n");
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("%d ", arr[i]);
#     }
#
#     return 0;
# }
# Out:
# Writing bubble_sort.c

# %%
# %%writefile insertion_sort.c
# #include <stdio.h>
#
# int main()
# {
#     int arr[100];
#     int n, key, j;
#
#     printf("========================================\n");
#     printf("        INSERTION SORT PROGRAM\n");
#     printf("========================================\n");
#
#     printf("Enter the number of elements: ");
#     scanf("%d", &n);
#
#     printf("\nEnter %d elements:\n", n);
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("Element %d: ", i + 1);
#         scanf("%d", &arr[i]);
#     }
#
#     for(int i = 1; i < n; i++)
#     {
#         key = arr[i];
#         j = i - 1;
#
#         while(j >= 0 && arr[j] > key)
#         {
#             arr[j + 1] = arr[j];
#             j--;
#         }
#
#         arr[j + 1] = key;
#     }
#
#     printf("\nSorted Array (Ascending Order):\n");
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("%d ", arr[i]);
#     }
#
#     return 0;
# }
# Out:
# Writing insertion_sort.c

# %%
# %%writefile selection_sort.c
# #include <stdio.h>
#
# int main()
# {
#     int arr[100];
#     int n;
#     int minIndex, temp;
#
#     printf("========================================\n");
#     printf("         SELECTION SORT PROGRAM\n");
#     printf("========================================\n");
#
#     printf("Enter the number of elements: ");
#     scanf("%d", &n);
#
#     printf("\nEnter %d elements:\n", n);
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("Element %d: ", i + 1);
#         scanf("%d", &arr[i]);
#     }
#
#     for(int i = 0; i < n - 1; i++)
#     {
#         minIndex = i;
#
#         for(int j = i + 1; j < n; j++)
#         {
#             if(arr[j] < arr[minIndex])
#             {
#                 minIndex = j;
#             }
#         }
#
#         temp = arr[i];
#         arr[i] = arr[minIndex];
#         arr[minIndex] = temp;
#     }
#
#     printf("\nSorted Array (Ascending Order):\n");
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("%d ", arr[i]);
#     }
#
#     return 0;
# }
# Out:
# Writing selection_sort.c

# %%
# %%writefile merge_sort.c
# #include <stdio.h>
#
# void merge(int arr[], int left, int mid, int right)
# {
#     int n1 = mid - left + 1;
#     int n2 = right - mid;
#
#     int L[100], R[100];
#
#     for(int i = 0; i < n1; i++)
#         L[i] = arr[left + i];
#
#     for(int j = 0; j < n2; j++)
#         R[j] = arr[mid + 1 + j];
#
#     int i = 0;
#     int j = 0;
#     int k = left;
#
#     while(i < n1 && j < n2)
#     {
#         if(L[i] <= R[j])
#         {
#             arr[k] = L[i];
#             i++;
#         }
#         else
#         {
#             arr[k] = R[j];
#             j++;
#         }
#         k++;
#     }
#
#     while(i < n1)
#     {
#         arr[k] = L[i];
#         i++;
#         k++;
#     }
#
#     while(j < n2)
#     {
#         arr[k] = R[j];
#         j++;
#         k++;
#     }
# }
#
# void mergeSort(int arr[], int left, int right)
# {
#     if(left < right)
#     {
#         int mid = left + (right - left) / 2;
#
#         mergeSort(arr, left, mid);
#         mergeSort(arr, mid + 1, right);
#
#         merge(arr, left, mid, right);
#     }
# }
#
# int main()
# {
#     int arr[100];
#     int n;
#
#     printf("========================================\n");
#     printf("           MERGE SORT PROGRAM\n");
#     printf("========================================\n");
#
#     printf("Enter the number of elements: ");
#     scanf("%d", &n);
#
#     printf("\nEnter %d elements:\n", n);
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("Element %d: ", i + 1);
#         scanf("%d", &arr[i]);
#     }
#
#     mergeSort(arr, 0, n - 1);
#
#     printf("\nSorted Array (Ascending Order):\n");
#
#     for(int i = 0; i < n; i++)
#     {
#         printf("%d ", arr[i]);
#     }
#
#     return 0;
# }
# Out:
# Writing merge_sort.c

# %%
# %%writefile generic_tree.c
# #include <stdio.h>
#
# struct TreeNode
# {
#     char data;
#     struct TreeNode *child1;
#     struct TreeNode *child2;
#     struct TreeNode *child3;
# };
#
# int main()
# {
#     struct TreeNode A = {'A', NULL, NULL, NULL};
#     struct TreeNode B = {'B', NULL, NULL, NULL};
#     struct TreeNode C = {'C', NULL, NULL, NULL};
#     struct TreeNode D = {'D', NULL, NULL, NULL};
#
#     A.child1 = &B;
#     A.child2 = &C;
#     A.child3 = &D;
#
#     printf("Root Node : %c\n", A.data);
#     printf("Children  : %c %c %c\n",
#            A.child1->data,
#            A.child2->data,
#            A.child3->data);
#
#     return 0;
# }
# Out:
# Writing generic_tree.c

# %%
# %%writefile binary_tree_creation.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *newNode = (struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data = value;
#     newNode->left = NULL;
#     newNode->right = NULL;
#
#     return newNode;
# }
#
# int main()
# {
#     struct Node *root = createNode(10);
#
#     root->left = createNode(20);
#     root->right = createNode(30);
#
#     root->left->left = createNode(40);
#     root->left->right = createNode(50);
#
#     printf("Root       : %d\n", root->data);
#     printf("Left Child : %d\n", root->left->data);
#     printf("Right Child: %d\n", root->right->data);
#
#     return 0;
# }
# Out:
# Writing binary_tree_creation.c

# %%
# %%writefile binary_tree_height.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *newNode = (struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data = value;
#     newNode->left = NULL;
#     newNode->right = NULL;
#
#     return newNode;
# }
#
# int height(struct Node *root)
# {
#     if(root == NULL)
#         return 0;
#
#     int leftHeight = height(root->left);
#     int rightHeight = height(root->right);
#
#     return (leftHeight > rightHeight ? leftHeight : rightHeight) + 1;
# }
#
# int main()
# {
#     struct Node *root = createNode(1);
#
#     root->left = createNode(2);
#     root->right = createNode(3);
#
#     root->left->left = createNode(4);
#     root->left->right = createNode(5);
#
#     printf("Height of Tree = %d\n", height(root));
#
#     return 0;
# }
# Out:
# Writing binary_tree_height.c

# %%
# %%writefile leaf_node_count.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *newNode = (struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data = value;
#     newNode->left = NULL;
#     newNode->right = NULL;
#
#     return newNode;
# }
#
# int countLeaves(struct Node *root)
# {
#     if(root == NULL)
#         return 0;
#
#     if(root->left == NULL && root->right == NULL)
#         return 1;
#
#     return countLeaves(root->left) + countLeaves(root->right);
# }
#
# int main()
# {
#     struct Node *root = createNode(10);
#
#     root->left = createNode(20);
#     root->right = createNode(30);
#
#     root->left->left = createNode(40);
#     root->left->right = createNode(50);
#
#     printf("Leaf Nodes = %d\n", countLeaves(root));
#
#     return 0;
# }
# Out:
# Writing leaf_node_count.c

# %%
# %%writefile lcrs_tree.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     char data;
#     struct Node *leftChild;
#     struct Node *rightSibling;
# };
#
# struct Node* createNode(char value)
# {
#     struct Node *newNode = (struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data = value;
#     newNode->leftChild = NULL;
#     newNode->rightSibling = NULL;
#
#     return newNode;
# }
#
# int main()
# {
#     struct Node *A = createNode('A');
#     struct Node *B = createNode('B');
#     struct Node *C = createNode('C');
#     struct Node *D = createNode('D');
#
#     A->leftChild = B;
#     B->rightSibling = C;
#     C->rightSibling = D;
#
#     printf("Root        : %c\n", A->data);
#     printf("First Child : %c\n", A->leftChild->data);
#     printf("Sibling     : %c\n", A->leftChild->rightSibling->data);
#
#     return 0;
# }
# Out:
# Writing lcrs_tree.c

# %%
# %%writefile binary_tree_creation.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *newNode = (struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data = value;
#     newNode->left = NULL;
#     newNode->right = NULL;
#
#     return newNode;
# }
#
# int main()
# {
#     struct Node *root = createNode(1);
#
#     root->left = createNode(2);
#     root->right = createNode(3);
#
#     root->left->left = createNode(4);
#     root->left->right = createNode(5);
#
#     printf("Root Node      : %d\n", root->data);
#     printf("Left Child     : %d\n", root->left->data);
#     printf("Right Child    : %d\n", root->right->data);
#
#     return 0;
# }
# Out:
# Overwriting binary_tree_creation.c

# %%
# %%writefile preorder_traversal.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node = (struct Node*)malloc(sizeof(struct Node));
#
#     node->data = value;
#     node->left = NULL;
#     node->right = NULL;
#
#     return node;
# }
#
# void preorder(struct Node *root)
# {
#     if(root == NULL)
#         return;
#
#     printf("%d ", root->data);
#
#     preorder(root->left);
#     preorder(root->right);
# }
#
# int main()
# {
#     struct Node *root = createNode(1);
#
#     root->left = createNode(2);
#     root->right = createNode(3);
#
#     root->left->left = createNode(4);
#     root->left->right = createNode(5);
#
#     printf("Preorder Traversal:\n");
#
#     preorder(root);
#
#     return 0;
# }
# Out:
# Writing preorder_traversal.c

# %%
# %%writefile inorder_traversal.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node = (struct Node*)malloc(sizeof(struct Node));
#
#     node->data = value;
#     node->left = NULL;
#     node->right = NULL;
#
#     return node;
# }
#
# void inorder(struct Node *root)
# {
#     if(root == NULL)
#         return;
#
#     inorder(root->left);
#
#     printf("%d ", root->data);
#
#     inorder(root->right);
# }
#
# int main()
# {
#     struct Node *root = createNode(1);
#
#     root->left = createNode(2);
#     root->right = createNode(3);
#
#     root->left->left = createNode(4);
#     root->left->right = createNode(5);
#
#     printf("Inorder Traversal:\n");
#
#     inorder(root);
#
#     return 0;
# }
# Out:
# Writing inorder_traversal.c

# %%
# %%writefile postorder_traversal.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node = (struct Node*)malloc(sizeof(struct Node));
#
#     node->data = value;
#     node->left = NULL;
#     node->right = NULL;
#
#     return node;
# }
#
# void postorder(struct Node *root)
# {
#     if(root == NULL)
#         return;
#
#     postorder(root->left);
#
#     postorder(root->right);
#
#     printf("%d ", root->data);
# }
#
# int main()
# {
#     struct Node *root = createNode(1);
#
#     root->left = createNode(2);
#     root->right = createNode(3);
#
#     root->left->left = createNode(4);
#     root->left->right = createNode(5);
#
#     printf("Postorder Traversal:\n");
#
#     postorder(root);
#
#     return 0;
# }
# Out:
# Writing postorder_traversal.c

# %%
# %%writefile level_order_traversal.c
# #include <stdio.h>
# #include <stdlib.h>
#
# #define MAX 100
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node *queue[MAX];
# int front = -1;
# int rear = -1;
#
# struct Node* createNode(int value)
# {
#     struct Node *node = (struct Node*)malloc(sizeof(struct Node));
#
#     node->data = value;
#     node->left = NULL;
#     node->right = NULL;
#
#     return node;
# }
#
# void enqueue(struct Node *node)
# {
#     if(front == -1)
#         front = 0;
#
#     queue[++rear] = node;
# }
#
# struct Node* dequeue()
# {
#     return queue[front++];
# }
#
# int isEmpty()
# {
#     return front > rear;
# }
#
# void levelOrder(struct Node *root)
# {
#     if(root == NULL)
#         return;
#
#     enqueue(root);
#
#     while(!isEmpty())
#     {
#         struct Node *temp = dequeue();
#
#         printf("%d ", temp->data);
#
#         if(temp->left)
#             enqueue(temp->left);
#
#         if(temp->right)
#             enqueue(temp->right);
#     }
# }
#
# int main()
# {
#     struct Node *root = createNode(1);
#
#     root->left = createNode(2);
#     root->right = createNode(3);
#
#     root->left->left = createNode(4);
#     root->left->right = createNode(5);
#
#     root->right->left = createNode(6);
#     root->right->right = createNode(7);
#
#     printf("Level Order Traversal:\n");
#
#     levelOrder(root);
#
#     return 0;
# }
# Out:
# Writing level_order_traversal.c

# %%
# %%writefile level_order_traversal.c
# #include <stdio.h>
# #include <stdlib.h>
#
# #define MAX 100
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node *queue[MAX];
# int front = -1;
# int rear = -1;
#
# struct Node* createNode(int value)
# {
#     struct Node *node = (struct Node*)malloc(sizeof(struct Node));
#
#     node->data = value;
#     node->left = NULL;
#     node->right = NULL;
#
#     return node;
# }
#
# void enqueue(struct Node *node)
# {
#     if(front == -1)
#         front = 0;
#
#     queue[++rear] = node;
# }
#
# struct Node* dequeue()
# {
#     return queue[front++];
# }
#
# int isEmpty()
# {
#     return front > rear;
# }
#
# void levelOrder(struct Node *root)
# {
#     if(root == NULL)
#         return;
#
#     enqueue(root);
#
#     while(!isEmpty())
#     {
#         struct Node *temp = dequeue();
#
#         printf("%d ", temp->data);
#
#         if(temp->left)
#             enqueue(temp->left);
#
#         if(temp->right)
#             enqueue(temp->right);
#     }
# }
#
# int main()
# {
#     struct Node *root = createNode(1);
#
#     root->left = createNode(2);
#     root->right = createNode(3);
#
#     root->left->left = createNode(4);
#     root->left->right = createNode(5);
#
#     root->right->left = createNode(6);
#     root->right->right = createNode(7);
#
#     printf("Level Order Traversal:\n");
#
#     levelOrder(root);
#
#     return 0;
# }
# Out:
# Overwriting level_order_traversal.c

# %%
# %%writefile heap_relationship.c
# #include <stdio.h>
#
# int main()
# {
#     int heap[] = {50,30,20,15,10,8,16};
#     int size = sizeof(heap)/sizeof(heap[0]);
#
#     printf("Heap Relationships\n\n");
#
#     for(int i=0;i<size;i++)
#     {
#         printf("Node %d\n", heap[i]);
#
#         if((2*i+1)<size)
#             printf(" Left Child  : %d\n",heap[2*i+1]);
#
#         if((2*i+2)<size)
#             printf(" Right Child : %d\n",heap[2*i+2]);
#
#         if(i!=0)
#             printf(" Parent      : %d\n",heap[(i-1)/2]);
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing heap_relationship.c

# %%
# %%writefile heap_insertion.c
# #include <stdio.h>
#
# void heapifyUp(int heap[], int index)
# {
#     while(index > 0)
#     {
#         int parent = (index - 1) / 2;
#
#         if(heap[parent] < heap[index])
#         {
#             int temp = heap[parent];
#             heap[parent] = heap[index];
#             heap[index] = temp;
#
#             index = parent;
#         }
#         else
#         {
#             break;
#         }
#     }
# }
#
# int main()
# {
#     int heap[20] = {50,30,20,15,10,8,16};
#     int size = 7;
#
#     int value = 40;
#
#     heap[size] = value;
#     heapifyUp(heap,size);
#
#     size++;
#
#     printf("Heap after Insertion\n\n");
#
#     for(int i=0;i<size;i++)
#     {
#         printf("%d ",heap[i]);
#     }
#
#     return 0;
# }
# Out:
# Writing heap_insertion.c

# %%
# %%writefile heap_deletion.c
# #include <stdio.h>
#
# void heapifyDown(int heap[], int size, int index)
# {
#     while(1)
#     {
#         int largest = index;
#         int left = 2*index+1;
#         int right = 2*index+2;
#
#         if(left<size && heap[left]>heap[largest])
#             largest=left;
#
#         if(right<size && heap[right]>heap[largest])
#             largest=right;
#
#         if(largest!=index)
#         {
#             int temp=heap[index];
#             heap[index]=heap[largest];
#             heap[largest]=temp;
#
#             index=largest;
#         }
#         else
#             break;
#     }
# }
#
# int main()
# {
#     int heap[] = {50,30,20,15,10,8,16};
#     int size = 7;
#
#     heap[0]=heap[size-1];
#     size--;
#
#     heapifyDown(heap,size,0);
#
#     printf("Heap after Deletion\n\n");
#
#     for(int i=0;i<size;i++)
#     {
#         printf("%d ",heap[i]);
#     }
#
#     return 0;
# }
# Out:
# Writing heap_deletion.c

# %%
# %%writefile tree_search_bfs.c
# #include <stdio.h>
# #include <stdlib.h>
#
# #define MAX 100
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node *queue[MAX];
# int front=-1,rear=-1;
#
# struct Node* createNode(int value)
# {
#     struct Node *node=(struct Node*)malloc(sizeof(struct Node));
#
#     node->data=value;
#     node->left=NULL;
#     node->right=NULL;
#
#     return node;
# }
#
# void enqueue(struct Node *node)
# {
#     if(front==-1)
#         front=0;
#
#     queue[++rear]=node;
# }
#
# struct Node* dequeue()
# {
#     return queue[front++];
# }
#
# int isEmpty()
# {
#     return front>rear;
# }
#
# void search(struct Node *root,int key)
# {
#     enqueue(root);
#
#     while(!isEmpty())
#     {
#         struct Node *temp=dequeue();
#
#         if(temp->data==key)
#         {
#             printf("Node %d Found\n",key);
#             return;
#         }
#
#         if(temp->left)
#             enqueue(temp->left);
#
#         if(temp->right)
#             enqueue(temp->right);
#     }
#
#     printf("Node Not Found\n");
# }
#
# int main()
# {
#     struct Node *root=createNode(1);
#
#     root->left=createNode(2);
#     root->right=createNode(3);
#
#     root->left->left=createNode(4);
#     root->left->right=createNode(5);
#
#     root->right->left=createNode(6);
#     root->right->right=createNode(7);
#
#     search(root,6);
#
#     return 0;
# }
# Out:
# Writing tree_search_bfs.c

# %%
# %%writefile bst_creation.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *newNode = (struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data = value;
#     newNode->left = NULL;
#     newNode->right = NULL;
#
#     return newNode;
# }
#
# int main()
# {
#     struct Node *root = createNode(50);
#
#     printf("Root Node : %d\n", root->data);
#
#     return 0;
# }
# Out:
# Writing bst_creation.c

# %%
# %%writefile bst_insertion.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *newNode=(struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data=value;
#     newNode->left=NULL;
#     newNode->right=NULL;
#
#     return newNode;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value < root->data)
#         root->left=insert(root->left,value);
#
#     else if(value > root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# void inorder(struct Node *root)
# {
#     if(root==NULL)
#         return;
#
#     inorder(root->left);
#
#     printf("%d ",root->data);
#
#     inorder(root->right);
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     root=insert(root,50);
#     root=insert(root,30);
#     root=insert(root,70);
#     root=insert(root,20);
#     root=insert(root,40);
#     root=insert(root,60);
#     root=insert(root,80);
#
#     printf("BST (Inorder Traversal): ");
#
#     inorder(root);
#
#     return 0;
# }
# Out:
# Writing bst_insertion.c

# %%
# %%writefile bst_search.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *newNode=(struct Node*)malloc(sizeof(struct Node));
#
#     newNode->data=value;
#     newNode->left=NULL;
#     newNode->right=NULL;
#
#     return newNode;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value < root->data)
#         root->left=insert(root->left,value);
#
#     else if(value > root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# struct Node* search(struct Node *root,int key)
# {
#     if(root==NULL || root->data==key)
#         return root;
#
#     if(key < root->data)
#         return search(root->left,key);
#
#     return search(root->right,key);
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     root=insert(root,50);
#     root=insert(root,30);
#     root=insert(root,70);
#     root=insert(root,20);
#     root=insert(root,40);
#     root=insert(root,60);
#     root=insert(root,80);
#
#     int key=60;
#
#     if(search(root,key))
#         printf("%d Found in BST\n",key);
#     else
#         printf("%d Not Found\n",key);
#
#     return 0;
# }
# Out:
# Writing bst_search.c

# %%
# %%writefile bst_user_input.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node=(struct Node*)malloc(sizeof(struct Node));
#
#     node->data=value;
#     node->left=NULL;
#     node->right=NULL;
#
#     return node;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value < root->data)
#         root->left=insert(root->left,value);
#
#     else if(value > root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# void inorder(struct Node *root)
# {
#     if(root==NULL)
#         return;
#
#     inorder(root->left);
#
#     printf("%d ",root->data);
#
#     inorder(root->right);
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     int n,value;
#
#     printf("Enter Number of Nodes : ");
#     scanf("%d",&n);
#
#     for(int i=1;i<=n;i++)
#     {
#         printf("Enter Value %d : ",i);
#         scanf("%d",&value);
#
#         root=insert(root,value);
#     }
#
#     printf("\nBST (Sorted Order): ");
#
#     inorder(root);
#
#     return 0;
# }
# Out:
# Writing bst_user_input.c

# %%
# %%writefile bst_operations.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node=(struct Node*)malloc(sizeof(struct Node));
#
#     node->data=value;
#     node->left=NULL;
#     node->right=NULL;
#
#     return node;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value < root->data)
#         root->left=insert(root->left,value);
#
#     else if(value > root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# struct Node* search(struct Node *root,int key)
# {
#     if(root==NULL || root->data==key)
#         return root;
#
#     if(key < root->data)
#         return search(root->left,key);
#
#     return search(root->right,key);
# }
#
# void inorder(struct Node *root)
# {
#     if(root==NULL)
#         return;
#
#     inorder(root->left);
#
#     printf("%d ",root->data);
#
#     inorder(root->right);
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     int values[]={50,30,70,20,40,60,80};
#
#     for(int i=0;i<7;i++)
#         root=insert(root,values[i]);
#
#     printf("BST (Inorder): ");
#
#     inorder(root);
#
#     int key=40;
#
#     if(search(root,key))
#         printf("\n\n%d Found in BST\n",key);
#     else
#         printf("\n\n%d Not Found\n",key);
#
#     return 0;
# }
# Out:
# Writing bst_operations.c

# %%
# %%writefile bst_delete_leaf.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node = (struct Node*)malloc(sizeof(struct Node));
#     node->data = value;
#     node->left = NULL;
#     node->right = NULL;
#     return node;
# }
#
# struct Node* insert(struct Node *root, int value)
# {
#     if(root == NULL)
#         return createNode(value);
#
#     if(value < root->data)
#         root->left = insert(root->left, value);
#     else if(value > root->data)
#         root->right = insert(root->right, value);
#
#     return root;
# }
#
# struct Node* deleteLeaf(struct Node *root, int key)
# {
#     if(root == NULL)
#         return NULL;
#
#     if(key < root->data)
#         root->left = deleteLeaf(root->left, key);
#
#     else if(key > root->data)
#         root->right = deleteLeaf(root->right, key);
#
#     else
#     {
#         if(root->left == NULL && root->right == NULL)
#         {
#             free(root);
#             return NULL;
#         }
#     }
#
#     return root;
# }
#
# void inorder(struct Node *root)
# {
#     if(root == NULL)
#         return;
#
#     inorder(root->left);
#     printf("%d ", root->data);
#     inorder(root->right);
# }
#
# int main()
# {
#     struct Node *root = NULL;
#
#     int values[] = {50,30,70,20,40,60,80};
#
#     for(int i=0;i<7;i++)
#         root = insert(root, values[i]);
#
#     root = deleteLeaf(root,20);
#
#     printf("BST After Deleting Leaf Node:\n");
#
#     inorder(root);
#
#     return 0;
# }
# Out:
# Writing bst_delete_leaf.c

# %%
# %%writefile bst_delete_one_child.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node=(struct Node*)malloc(sizeof(struct Node));
#
#     node->data=value;
#     node->left=NULL;
#     node->right=NULL;
#
#     return node;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value<root->data)
#         root->left=insert(root->left,value);
#     else if(value>root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# struct Node* deleteOneChild(struct Node *root,int key)
# {
#     if(root==NULL)
#         return NULL;
#
#     if(key<root->data)
#         root->left=deleteOneChild(root->left,key);
#
#     else if(key>root->data)
#         root->right=deleteOneChild(root->right,key);
#
#     else
#     {
#         if(root->left==NULL)
#         {
#             struct Node *temp=root->right;
#             free(root);
#             return temp;
#         }
#
#         if(root->right==NULL)
#         {
#             struct Node *temp=root->left;
#             free(root);
#             return temp;
#         }
#     }
#
#     return root;
# }
#
# void inorder(struct Node *root)
# {
#     if(root==NULL)
#         return;
#
#     inorder(root->left);
#     printf("%d ",root->data);
#     inorder(root->right);
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     root=insert(root,50);
#     root=insert(root,30);
#     root=insert(root,70);
#     root=insert(root,60);
#
#     root=deleteOneChild(root,70);
#
#     inorder(root);
#
#     return 0;
# }
# Out:
# Writing bst_delete_one_child.c

# %%
# %%writefile bst_delete_two_children.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node=(struct Node*)malloc(sizeof(struct Node));
#
#     node->data=value;
#     node->left=NULL;
#     node->right=NULL;
#
#     return node;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value<root->data)
#         root->left=insert(root->left,value);
#     else if(value>root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# struct Node* minimum(struct Node *root)
# {
#     while(root->left!=NULL)
#         root=root->left;
#
#     return root;
# }
#
# struct Node* deleteNode(struct Node *root,int key)
# {
#     if(root==NULL)
#         return NULL;
#
#     if(key<root->data)
#         root->left=deleteNode(root->left,key);
#
#     else if(key>root->data)
#         root->right=deleteNode(root->right,key);
#
#     else
#     {
#         if(root->left==NULL)
#         {
#             struct Node *temp=root->right;
#             free(root);
#             return temp;
#         }
#
#         if(root->right==NULL)
#         {
#             struct Node *temp=root->left;
#             free(root);
#             return temp;
#         }
#
#         struct Node *temp=minimum(root->right);
#
#         root->data=temp->data;
#
#         root->right=deleteNode(root->right,temp->data);
#     }
#
#     return root;
# }
#
# void inorder(struct Node *root)
# {
#     if(root==NULL)
#         return;
#
#     inorder(root->left);
#     printf("%d ",root->data);
#     inorder(root->right);
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     int values[]={50,30,70,20,40,60,80};
#
#     for(int i=0;i<7;i++)
#         root=insert(root,values[i]);
#
#     root=deleteNode(root,50);
#
#     inorder(root);
#
#     return 0;
# }
# Out:
# Writing bst_delete_two_children.c

# %%
# %%writefile bst_complete_deletion.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node=(struct Node*)malloc(sizeof(struct Node));
#
#     node->data=value;
#     node->left=node->right=NULL;
#
#     return node;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value<root->data)
#         root->left=insert(root->left,value);
#     else if(value>root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# struct Node* minimum(struct Node *root)
# {
#     while(root->left)
#         root=root->left;
#
#     return root;
# }
#
# struct Node* deleteNode(struct Node *root,int key)
# {
#     if(root==NULL)
#         return NULL;
#
#     if(key<root->data)
#         root->left=deleteNode(root->left,key);
#
#     else if(key>root->data)
#         root->right=deleteNode(root->right,key);
#
#     else
#     {
#         if(root->left==NULL)
#         {
#             struct Node *temp=root->right;
#             free(root);
#             return temp;
#         }
#
#         if(root->right==NULL)
#         {
#             struct Node *temp=root->left;
#             free(root);
#             return temp;
#         }
#
#         struct Node *temp=minimum(root->right);
#
#         root->data=temp->data;
#
#         root->right=deleteNode(root->right,temp->data);
#     }
#
#     return root;
# }
#
# void inorder(struct Node *root)
# {
#     if(root)
#     {
#         inorder(root->left);
#         printf("%d ",root->data);
#         inorder(root->right);
#     }
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     int arr[]={50,30,70,20,40,60,80};
#
#     for(int i=0;i<7;i++)
#         root=insert(root,arr[i]);
#
#     printf("Before Deletion:\n");
#     inorder(root);
#
#     root=deleteNode(root,30);
#
#     printf("\n\nAfter Deletion:\n");
#     inorder(root);
#
#     return 0;
# }
# Out:
# Writing bst_complete_deletion.c

# %%
# %%writefile bst_height.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node
# {
#     int data;
#     struct Node *left;
#     struct Node *right;
# };
#
# struct Node* createNode(int value)
# {
#     struct Node *node=(struct Node*)malloc(sizeof(struct Node));
#
#     node->data=value;
#     node->left=node->right=NULL;
#
#     return node;
# }
#
# struct Node* insert(struct Node *root,int value)
# {
#     if(root==NULL)
#         return createNode(value);
#
#     if(value<root->data)
#         root->left=insert(root->left,value);
#     else if(value>root->data)
#         root->right=insert(root->right,value);
#
#     return root;
# }
#
# int height(struct Node *root)
# {
#     if(root==NULL)
#         return -1;
#
#     int leftHeight=height(root->left);
#     int rightHeight=height(root->right);
#
#     return (leftHeight>rightHeight?leftHeight:rightHeight)+1;
# }
#
# int main()
# {
#     struct Node *root=NULL;
#
#     int values[]={50,30,70,20,40,60,80};
#
#     for(int i=0;i<7;i++)
#         root=insert(root,values[i]);
#
#     printf("Height of BST = %d\n",height(root));
#
#     return 0;
# }
# Out:
# Writing bst_height.c

# %%
# %%writefile solid_square.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the size: ");
#     scanf("%d", &n);
#
#     for(int i = 1; i <= n; i++)
#     {
#         for(int j = 1; j <= n; j++)
#         {
#             printf("* ");
#         }
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing solid_square.c

# %%
# %%writefile hollow_square.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the size: ");
#     scanf("%d",&n);
#
#     for(int i=1;i<=n;i++)
#     {
#         for(int j=1;j<=n;j++)
#         {
#             if(i==1 || i==n || j==1 || j==n)
#                 printf("* ");
#             else
#                 printf("  ");
#         }
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing hollow_square.c

# %%
# %%writefile left_half_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=1;i<=n;i++)
#     {
#         for(int j=1;j<=i;j++)
#         {
#             printf("* ");
#         }
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing left_half_pyramid.c

# %%
# %%writefile inverted_half_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=n;i>=1;i--)
#     {
#         for(int j=1;j<=i;j++)
#         {
#             printf("* ");
#         }
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing inverted_half_pyramid.c

# %%
# %%writefile right_half_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=1;i<=n;i++)
#     {
#         for(int j=1;j<=n-i;j++)
#             printf("  ");
#
#         for(int j=1;j<=i;j++)
#             printf("* ");
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing right_half_pyramid.c

# %%
# %%writefile inverted_right_half_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=n;i>=1;i--)
#     {
#         for(int j=1;j<=n-i;j++)
#             printf("  ");
#
#         for(int j=1;j<=i;j++)
#             printf("* ");
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing inverted_right_half_pyramid.c

# %%
# %%writefile full_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=1;i<=n;i++)
#     {
#         for(int j=1;j<=n-i;j++)
#             printf(" ");
#
#         for(int j=1;j<=2*i-1;j++)
#             printf("*");
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing full_pyramid.c

# %%
# %%writefile inverted_full_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=n;i>=1;i--)
#     {
#         for(int j=1;j<=n-i;j++)
#             printf(" ");
#
#         for(int j=1;j<=2*i-1;j++)
#             printf("*");
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing inverted_full_pyramid.c

# %%
# %%writefile diamond_pattern.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=1;i<=n;i++)
#     {
#         for(int j=1;j<=n-i;j++)
#             printf(" ");
#
#         for(int j=1;j<=2*i-1;j++)
#             printf("*");
#
#         printf("\n");
#     }
#
#     for(int i=n-1;i>=1;i--)
#     {
#         for(int j=1;j<=n-i;j++)
#             printf(" ");
#
#         for(int j=1;j<=2*i-1;j++)
#             printf("*");
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing diamond_pattern.c

# %%
# %%writefile hollow_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d",&n);
#
#     for(int i=1;i<=n;i++)
#     {
#         for(int j=1;j<=n-i;j++)
#             printf(" ");
#
#         for(int j=1;j<=2*i-1;j++)
#         {
#             if(j==1 || j==2*i-1 || i==n)
#                 printf("*");
#             else
#                 printf(" ");
#         }
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing hollow_pyramid.c

# %%
# %%writefile floyd_triangle.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#     int num = 1;
#
#     printf("Enter the number of rows: ");
#     scanf("%d", &n);
#
#     for(int i = 1; i <= n; i++)
#     {
#         for(int j = 1; j <= i; j++)
#         {
#             printf("%d ", num);
#             num++;
#         }
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing floyd_triangle.c

# %%
# %%writefile number_pyramid.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d", &n);
#
#     for(int i = 1; i <= n; i++)
#     {
#         for(int j = 1; j <= i; j++)
#         {
#             printf("%d ", j);
#         }
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing number_pyramid.c

# %%
# %%writefile pascal_triangle.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#     int coefficient;
#
#     printf("Enter the number of rows: ");
#     scanf("%d", &n);
#
#     for(int i = 0; i < n; i++)
#     {
#         coefficient = 1;
#
#         for(int space = 1; space <= n - i; space++)
#         {
#             printf(" ");
#         }
#
#         for(int j = 0; j <= i; j++)
#         {
#             printf("%d ", coefficient);
#             coefficient = coefficient * (i - j) / (j + 1);
#         }
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing pascal_triangle.c

# %%
# %%writefile butterfly_pattern.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d", &n);
#
#     for(int i = 1; i <= n; i++)
#     {
#         for(int j = 1; j <= i; j++)
#             printf("*");
#
#         for(int j = 1; j <= 2 * (n - i); j++)
#             printf(" ");
#
#         for(int j = 1; j <= i; j++)
#             printf("*");
#
#         printf("\n");
#     }
#
#     for(int i = n - 1; i >= 1; i--)
#     {
#         for(int j = 1; j <= i; j++)
#             printf("*");
#
#         for(int j = 1; j <= 2 * (n - i); j++)
#             printf(" ");
#
#         for(int j = 1; j <= i; j++)
#             printf("*");
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing butterfly_pattern.c

# %%
# %%writefile hollow_diamond.c
# #include <stdio.h>
#
# int main()
# {
#     int n;
#
#     printf("Enter the number of rows: ");
#     scanf("%d", &n);
#
#     for(int i = 1; i <= n; i++)
#     {
#         for(int j = 1; j <= n - i; j++)
#             printf(" ");
#
#         for(int j = 1; j <= 2 * i - 1; j++)
#         {
#             if(j == 1 || j == 2 * i - 1)
#                 printf("*");
#             else
#                 printf(" ");
#         }
#
#         printf("\n");
#     }
#
#     for(int i = n - 1; i >= 1; i--)
#     {
#         for(int j = 1; j <= n - i; j++)
#             printf(" ");
#
#         for(int j = 1; j <= 2 * i - 1; j++)
#         {
#             if(j == 1 || j == 2 * i - 1)
#                 printf("*");
#             else
#                 printf(" ");
#         }
#
#         printf("\n");
#     }
#
#     return 0;
# }
# Out:
# Writing hollow_diamond.c
